# %% [markdown]
# Taller 1
#
# Bioinformatica para ciencias Omicas
#
# 2025-1
#
# Estudiante: Francisco J. Salamanca

# %% [markdown]
# 1. Crear una funcion que visualice la calidad de una secuencia segun su posicion

# %%
import pandas as pd
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('./src')  #ruta relativa a tu carpeta src
from visualizacion import visualizar_calidad

# %% [markdown]
# Para el fastq 1

# %%
visualizar_calidad("archivos fastqc/secuencia_calidad2.fastq")
# Out:
# /Users/fjosesala/Documents/GitHub/BFOC-2025-1/Taller1_Calidad/src/visualizacion.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_expandido_copia[cols_calidad] = df_expandido_copia[cols_calidad].applymap(

# %% [markdown]
# Para el fastq 2

# %%
visualizar_calidad("/Users/fjosesala/Documents/GitHub/BFOC-2025-1/Taller1_Calidad/secuencia_calidad.fastq")
# Out:
# /Users/fjosesala/Documents/GitHub/BFOC-2025-1/Taller1_Calidad/src/visualizacion.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_expandido_copia[cols_calidad] = df_expandido_copia[cols_calidad].applymap(
